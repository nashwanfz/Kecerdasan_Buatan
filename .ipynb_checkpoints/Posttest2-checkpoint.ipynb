# %%
# Import dulu semua library yang kepake
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Biar grafiknya lebih cakep
sns.set(style="whitegrid")

# %%
# Baca dataset
df = pd.read_csv("SuperStoreOrders.csv")

# Liat 5 baris teratas buat ngecek datanya
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  6/1/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  8/1/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  5/1/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  5/1/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  8/1/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#           category sub_category                 product_name sales quantity  \
# ...

# %%
# Bagian 1
# Disini kita mau ngeliat statistik dasar dari kolom angka
# Kayak mean, std, min, max, plus Q1, Q2 (median), Q3
stats = df.select_dtypes(include='number').describe().T

Q1 = df.select_dtypes(include='number').quantile(0.25)
Q2 = df.select_dtypes(include='number').quantile(0.50)
Q3 = df.select_dtypes(include='number').quantile(0.75)

stats['Q1'] = Q1
stats['Q2'] = Q2
stats['Q3'] = Q3

stats
# Out:
#                  count         mean         std       min      25%      50%  \
# quantity       51290.0     3.476545    2.278766     1.000     2.00     3.00
# discount       51290.0     0.142908    0.212280     0.000     0.00     0.00
# profit         51290.0    28.641740  174.424113 -6599.978     0.00     9.24
# shipping_cost  51290.0    26.375915   57.296804     0.000     2.61     7.79
# year           51290.0  2012.777208    1.098931  2011.000  2012.00  2013.00
#
#                    75%       max       Q1       Q2       Q3
# quantity          5.00    14.000     2.00     3.00     5.00
# discount          0.20     0.850     0.00     0.00     0.20
# profit           36.81  8399.976     0.00     9.24    36.81
# shipping_cost    24.45   933.570     2.61     7.79    24.45
# year           2014.00  2014.000  2012.00  2013.00  2014.00

# %%
# Bagian 2
# Nah ini kita ambil 10 data awal khusus yang tipe angka aja
df.select_dtypes(include='number').head(10)
# Out:
#    quantity  discount   profit  shipping_cost  year
# 0         2       0.0  106.140          35.46  2011
# 1         3       0.1   36.036           9.72  2011
# 2         4       0.0   29.640           8.17  2011
# 3         3       0.5  -26.055           4.82  2011
# 4         5       0.1   37.770           4.70  2011
# 5         2       0.1   15.342           1.80  2011
# 6         1       0.0    3.120          24.10  2011
# 7         1       0.1  110.412         125.32  2011
# 8         4       0.4 -319.464         107.10  2011
# 9         4       0.0  253.320          81.26  2011

# %%
# Bagian 3
# Kita bikin ringkasan dataset:
# - jumlah baris
# - jumlah kolom
# - jumlah kolom numerik
# - nama-nama kolom
info_dataset = pd.DataFrame({
    "Jumlah Record": [df.shape[0]],
    "Jumlah Attribute": [df.shape[1]],
    "Jumlah Attribute Numerik": [df.select_dtypes(include='number').shape[1]],
    "Nama Attribute": [list(df.columns)]
})

info_dataset
# Out:
#    Jumlah Record  Jumlah Attribute  Jumlah Attribute Numerik  \
# 0          51290                21                         5
#
#                                       Nama Attribute
# 0  [order_id, order_date, ship_date, ship_mode, c...

# %%
# Bagian 4
# Cek berapa banyak kategori unik dari tiap kolom yang tipe object
object_cols = df.select_dtypes(include='object')

label_counts = pd.DataFrame({
    "Attribute": object_cols.columns,
    "Jumlah Label Unik": [df[col].nunique() for col in object_cols.columns]
})

label_counts
# Out:
#          Attribute  Jumlah Label Unik
# 0         order_id              25035
# 1       order_date               1430
# 2        ship_date               1464
# 3        ship_mode                  4
# 4    customer_name                795
# 5          segment                  3
# 6            state               1094
# 7          country                147
# 8           market                  7
# 9           region                 13
# 10      product_id              10292
# 11        category                  3
# 12    sub_category                 17
# 13    product_name               3788
# 14           sales               2246
# 15  order_priority                  4

# %%
# Bagian 5
#kita liat distribusi sales pake histogram + KDE biar keliatan polanya
plt.figure(figsize=(8,5))
sns.histplot(df['sales'], bins=50, kde=True)
plt.title("Distribusi Penjualan (Sales)")
plt.xlabel("Sales")
plt.ylabel("Frekuensi")
plt.show()

# %%
# Bagian 6
# Bikin heatmap buat liat hubungan antar kolom numerik
plt.figure(figsize=(8,6))
corr = df.select_dtypes(include='number').corr()
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Heatmap Korelasi Atribut Numerik")
plt.show()

# %% [markdown]
# Kesimpulan
# - Distribusi kolom Sales condong ke kanan atau right skewed artinya mayoritas penjualan bernilai kecil sementara ada beberapa transaksi dengan nilai sangat besar
# - Kolom Profit memiliki variasi besar terdapat transaksi yang merugi bernilai negatif dan ada juga yang untung besar bernilai positif
# - Hasil korelasi menunjukkan
#   - Kolom Sales cukup berhubungan dengan kolom Profit
#   - Kolom Discount berkorelasi negatif dengan kolom Profit semakin besar diskon maka profit cenderung menurun
#   - Kolom Quantity dan kolom Shipping Cost tidak memiliki pengaruh yang kuat terhadap kolom Profit
# - Sebagian besar transaksi dilakukan dengan jumlah barang yang relatif kecil biasanya hanya beberapa unit saja
